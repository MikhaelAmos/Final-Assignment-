# %%
# %config Completer.use_jedi = False
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
import glob
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import uniform
from sklearn.linear_model import Lasso, ElasticNet, Ridge, LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
import pandas as pd
import numpy as np

import glob

import matplotlib.pyplot as plt

# %%
flist=glob.glob("kalkulasi/*")

# %%
well_name = []
gr_hist = []
nphi_hist = []
rhob_hist = []
rt_hist = []
Vshale_hist = []
# PHIE_hist = []
PHIE_hist = []
PHIT_hist = []
Sw_hist= []

gr_ticks = np.linspace(0,150,51) 
nphi_ticks = np.linspace(0,1,51) 
rhob_ticks = np.linspace(1,3,51) 
rt_ticks = np.linspace(-1,2,51) 
Vshale_ticks = np.linspace(0,1,51) 
# PHIE_ticks = np.linspace(0,1,51) 
PHIE_ticks = np.linspace(0,1,51) 
PHIT_ticks = np.linspace(0,1,51) 
Sw_ticks = np.linspace(0,1,51) 

gr_stats = []
nphi_stats = []
rhob_stats = []
rt_stats = []
Vshale_stats = []
# PHIE_stats = []
PHIE_stats = []
PHIT_stats = []
Sw_stats = []

for file in flist:
    try:
        df = pd.read_csv(file)
        well_name.append(file.split('\\')[-1].replace('.csv', ''))
        gr_hist.append(np.histogram(df.GR, bins=50, range=(0,150))[0].tolist())
        nphi_hist.append(np.histogram(df.NPHI, bins=50, range=(0,1))[0].tolist())
        rhob_hist.append(np.histogram(df.RHOB, bins=50, range=(1,3))[0].tolist())
        rt_hist.append(np.histogram(np.log10(df.RT), bins=50, range=(-1,2))[0].tolist())
        Vshale_hist.append(np.histogram(df.Vshale, bins=50, range=(0,1))[0].tolist())
#         PHIE_hist.append(np.histogram(df.PHIE, bins=50, range=(0,1))[0].tolist())
        PHIE_hist.append(np.histogram(df.PHIE, bins=50, range=(0,1))[0].tolist())
        PHIT_hist.append(np.histogram(df.PHIE, bins=50, range=(0,1))[0].tolist())
        Sw_hist.append(np.histogram(df.Sw, bins=50, range=(0,1))[0].tolist())
        
        gr_stats.append([df.GR.mean(), np.percentile(df.GR, 5), np.percentile(df.GR, 95), np.var(df.GR)])
        nphi_stats.append([df.NPHI.mean(), np.percentile(df.NPHI, 5), np.percentile(df.NPHI, 95), np.var(df.NPHI)])
        rhob_stats.append([df.RHOB.mean(), np.percentile(df.RHOB, 5), np.percentile(df.RHOB, 95), np.var(df.RHOB)])
        rt_stats.append([np.mean(np.log10(df.RT)), np.percentile(np.log10(df.RT), 5), np.percentile(np.log10(df.RT), 95), np.var(np.log10(df.RT))])
        Vshale_stats.append([df.Vshale.mean(), np.percentile(df.Vshale, 5), np.percentile(df.Vshale, 95), np.var(df.Vshale)])
#         PHIE_stats.append([df.PHIE.mean(), np.percentile(df.PHIE, 5), np.percentile(df.PHIE, 95), np.var(df.PHIE)])
        PHIE_stats.append([df.PHIE.mean(), np.percentile(df.PHIE, 5), np.percentile(df.PHIE, 95), np.var(df.PHIE)])
        PHIT_stats.append([df.PHIT.mean(), np.percentile(df.PHIT, 5), np.percentile(df.PHIT, 95), np.var(df.PHIT)])
        Sw_stats.append([df.Sw.mean(), np.percentile(df.Sw, 5), np.percentile(df.Sw, 95), np.var(df.Sw)])
    except Exception as e:
        print(file, e)

        
gr_hist = np.array(gr_hist)
nphi_hist = np.array(nphi_hist)
rhob_hist = np.array(rhob_hist)
rt_hist = np.array(rt_hist)
Vshale_hist = np.array(Vshale_hist)
# PHIE_hist = np.array(PHIE_hist)
PHIE_hist = np.array(PHIE_hist)
PHIT_hist = np.array(PHIT_hist)
Sw_hist = np.array(Sw_hist)

gr_hist = np.transpose((gr_hist.T - np.min(gr_hist,axis=1))/(np.max(gr_hist,axis=1) - np.min(gr_hist,axis=1)))
nphi_hist = np.transpose((nphi_hist.T - np.min(nphi_hist,axis=1))/(np.max(nphi_hist,axis=1) - np.min(nphi_hist,axis=1)))
rhob_hist = np.transpose((rhob_hist.T - np.min(rhob_hist,axis=1))/(np.max(rhob_hist,axis=1) - np.min(rhob_hist,axis=1)))
rt_hist = np.transpose((rt_hist.T - np.min(rt_hist,axis=1))/(np.max(rt_hist,axis=1) - np.min(rt_hist,axis=1)))
Vshale_hist = np.transpose((Vshale_hist.T - np.min(Vshale_hist,axis=1))/(np.max(Vshale_hist,axis=1) - np.min(Vshale_hist,axis=1)))
# PHIE_hist = np.transpose((PHIE_hist.T - np.min(PHIE_hist,axis=1))/(np.max(PHIE_hist,axis=1) - np.min(PHIE_hist,axis=1)))
PHIE_hist = np.transpose((PHIE_hist.T - np.min(PHIE_hist,axis=1))/(np.max(PHIE_hist,axis=1) - np.min(PHIE_hist,axis=1)))
PHIT_hist = np.transpose((PHIT_hist.T - np.min(PHIT_hist,axis=1))/(np.max(PHIT_hist,axis=1) - np.min(PHIT_hist,axis=1)))
Sw_hist = np.transpose((Sw_hist.T - np.min(Sw_hist,axis=1))/(np.max(Sw_hist,axis=1) - np.min(Sw_hist,axis=1)))

gr_stats = np.array(gr_stats).round(2)
nphi_stats = np.array(nphi_stats).round(2)
rhob_stats = np.array(rhob_stats).round(2)
rt_stats = np.array(rt_stats).round(2)
Vshale_stats = np.array(Vshale_stats).round(2)
# PHIE_stats = np.array(PHIE_stats).round(2)
PHIE_stats = np.array(PHIE_stats).round(2)
PHIT_stats = np.array(PHIT_stats).round(2)
Sw_stats = np.array(Sw_stats).round(2)

# %%
# plt.figure(figsize=(5,60))
# for num, i in enumerate(gr_hist):
#     plt.bar(range(len(gr_hist[0])), i, bottom=num)
    
# plt.xticks(np.arange(len(gr_ticks))[::5], np.int16(gr_ticks)[::5]);
# plt.yticks(np.arange(len(well_name))+0.5, well_name);
# plt.title('GR Histogram all well')

# %%
# plt.figure(figsize=(5,60))
# for num, i in enumerate(rhob_hist):
#     plt.bar(range(len(rhob_hist[0])), i, bottom=num)
    
# plt.xticks(np.arange(len(rhob_ticks))[::5], np.round(rhob_ticks,2)[::5]);
# plt.yticks(np.arange(len(well_name))+0.5, well_name);
# plt.title('RHOB Histogram all well')

# %%
# plt.figure(figsize=(5,60))
# for num, i in enumerate(nphi_hist):
#     plt.bar(range(len(nphi_hist[0])), i, bottom=num)
    
# plt.xticks(np.arange(len(nphi_ticks))[::5], np.round(nphi_ticks,2)[::5]);
# plt.yticks(np.arange(len(well_name))+0.5, well_name);
# plt.title('NPHI Histogram all well')

# %%
# plt.figure(figsize=(5,60))
# for num, i in enumerate(rt_hist):
#     plt.bar(range(len(rt_hist[0])), i, bottom=num)
    
# plt.xticks(np.arange(len(rt_ticks))[::5], np.round(np.power(10, rt_ticks),2)[::5], rotation=90);
# plt.yticks(np.arange(len(well_name))+0.5, well_name);
# plt.title('RT Histogram all well')

# %%
plt.figure(figsize=(5,60))
for num, i in enumerate(PHIE_hist):
    plt.bar(range(len(PHIE_hist[0])), i, bottom=num)
    
plt.xticks(np.arange(len(PHIE_ticks))[::5], np.round(PHIE_ticks,2)[::5]);
plt.yticks(np.arange(len(well_name))+0.5, well_name);
plt.title('PHIE Histogram all well')
# Out:
# Text(0.5, 1.0, 'PHIE Histogram all well')

# %%
plt.figure(figsize=(5,60))
for num, i in enumerate(PHIT_hist):
    plt.bar(range(len(PHIT_hist[0])), i, bottom=num)
    
plt.xticks(np.arange(len(PHIT_ticks))[::5], np.round(PHIT_ticks,2)[::5]);
plt.yticks(np.arange(len(well_name))+0.5, well_name);
plt.title('PHIT Histogram all well')
# Out:
# Text(0.5, 1.0, 'PHIT Histogram all well')

# %%
plt.figure(figsize=(5,60))
for num, i in enumerate(Vshale_hist):
    plt.bar(range(len(Vshale_hist[0])), i, bottom=num)
    
plt.xticks(np.arange(len(Vshale_ticks))[::5], np.round(Vshale_ticks,2)[::5]);
plt.yticks(np.arange(len(well_name))+0.5, well_name);

plt.title('Vshale Histogram all well')
# Out:
# Text(0.5, 1.0, 'Vshale Histogram all well')

# %%
plt.figure(figsize=(5,60))
for num, i in enumerate(Sw_hist):
    plt.bar(range(len(Sw_hist[0])), i, bottom=num)
    
plt.xticks(np.arange(len(Sw_ticks))[::5], np.round(Sw_ticks,2)[::5]);
plt.yticks(np.arange(len(well_name))+0.5, well_name);

plt.title('Sw Histogram all well')
# Out:
# Text(0.5, 1.0, 'Sw Histogram all well')

# %%
well_use = pd.DataFrame(np.c_[well_name,gr_stats[:,0], rhob_stats[:,0], nphi_stats[:,0], rt_stats[:,0]], 
             columns=['well name', 'gr mean', 'rhob mean', 'nphi mean', 'rt mean'])

# %%
well_use.round(2)
# Out:
#                       well name gr mean rhob mean nphi mean rt mean
# 0                  A. Goering 1   70.05      2.48      0.15    -inf
# 1                      Alan C-1   70.57      2.14      0.14    -inf
# 2                     Allyson 1   79.87      2.39      0.13    -inf
# 3                   Amstutz 1-8   65.11      2.41      0.11    -inf
# 4               Ankerholz 'A' 1   66.75      2.06      0.11    -inf
# 5             B.B. Ainsworth 13   65.19      2.43      0.15    -inf
# 6                 BARNHILL A 32   82.87      2.11      0.16    0.69
# 7                     Beagley 1   70.32      2.36      0.13    -inf
# 8                   Behnke 1-15   73.81      2.41      0.12    -inf
# 9                    Bell 'B' 3   67.37      2.23      0.15    -inf
# 10                      Berry 5   70.49      2.26       0.1    -inf
# 11                      Berry 6   85.56      2.35      0.18    -inf
# 12              BILLITER V 1-16   87.84      2.37      0.15    -inf
# 13                  Blackhall 5   68.75      2.35      0.15    -inf
# 14                Blankenship 1   84.59      2.53       0.1    -inf
# 15                    BNE 19-22    64.2      2.43      0.11    -inf
# 16   BONNEWELL-CARTER UNIT 18-1   70.13      2.41      0.13    -inf
# 17                    Boye 1-16   62.93     -0.02      0.12     0.7
# 18                     BOYE 1-9   72.66      2.38      0.19    -inf
# 19                    Brian C-1    74.8      2.09      0.16    -inf
# 20                  Brooks 1-13   74.64      2.55      0.11    -inf
# 21                      Brown 2   69.54      2.15      0.15    -inf
# 22            Browning 'C' 1-13   72.02      2.08      0.12    -inf
# 23                 Buckley 4-18   71.68      2.15      0.14    -inf
# 24            Buckley-Doll 1-18   61.49      2.15      0.11    -inf
# 25                   Burdette 1    72.5      2.43      0.18    -inf
# 26                 Cemetary C-2   70.92      2.08      0.15    -inf
# 27               Century Farm 1   81.82      2.37      0.15    -inf
# 28                   Comanche 1   76.08       2.5      0.11    -inf
# 29                  Connie 1-25   80.45      2.36      0.14    -inf
# 30                      Cross 4   55.75      2.22      0.14    -inf
# 31                    Cypress 4    64.6      2.09      0.16    0.76
# 32                    D & S 1-5   71.94      2.26      0.13    -inf
# 33             Dale Beneke 1-13   67.06      2.13      0.16    -inf
# 34             Dale Beneke 2-13   72.52      2.16      0.12    -inf
# 35             DELMAR KAUFMAN 1    64.9      2.47      0.21    0.64
# 36                  Dewitt 9-33   71.84      2.34      0.14    -inf
# 37                    Diamond 1   65.29      2.39      0.14    -inf
# 38                      Diana 1   63.44       2.2      0.18    -inf
# 39                     Disque 2   66.91      2.41      0.11    -inf
# 40                  Dobrinski 2   68.28      2.23     13.37    -inf
# 41                     Donald 3    65.7      2.22      0.15    -inf
# 42                  Dorothy 1-3    71.2      2.44      0.17    -inf
# 43                 E. Goering 5   69.15       2.5      0.14    -inf
# 44                Eatinger 3-21    63.3      2.48      0.14    -inf
# 45                     Enochs 1   71.51      2.08      0.13    -inf
# 46                    Evans 9-1   72.91      2.44      0.12    -inf
# 47                      Feist 8   64.75      2.26      0.15    -inf
# 48                   Fritz 1-31   69.24      2.44       0.2    -inf
# 49                   Garrison 4    66.1      2.25      0.11    -inf
# 50                GL Schmidt B1   70.72      2.09      0.12    -inf
# 51                    Godfrey 1   86.65      2.29       0.1    -inf
# 52                 Goering 1-23   60.25      2.51     21.96    0.68
# 53                  Goetz 'P' 1   66.71      2.33      0.16    -inf
# 54                  Goetz 'R' 1   63.62      2.17      0.14    -inf
# 55                      Goetz 2   58.97      2.39      0.16    -inf
# 56                    GOETZ A 1   62.05      2.19      0.17    -inf
# 57                     Govert 1   72.08      2.44      0.16    -inf
# 58                Grub Unit 1-5   68.82      2.18      0.13    -inf
# 59                Grub Unit 2-5   71.34       2.1      0.15    -inf
# 60                 HABIGER 18-1   68.84      2.45      0.12    -inf
# 61            Habiger Unit 1-14   67.81      2.11      0.15    -inf
# 62                    Hager C-1   66.31      2.23      0.17    -inf
# 63                  Hanson EMAW   74.95      2.52      0.13    -inf
# 64                     Harbin 2   71.58      2.18      0.11    -inf
# 65                     Harvey 1   74.85      2.45      0.11    -inf
# 66                      Hawk 16   78.48       2.2      0.14    -inf
# 67            Hedberg Unit 14-1   62.59      2.48      0.12    -inf
# 68                      Heine 3   77.68      2.05      0.16    -inf
# 69                     Heller 1   74.27       2.3      0.14    -inf
# 70                  Helten 2-35   67.95      2.42      0.14    0.78
# 71               Hoelscher 2-27   75.29      2.54      14.3    1.22
# 72               Hoelscher 3-10   73.43       2.1      0.18    -inf
# 73               Hoelscher 4-10   69.62      2.28      0.14    -inf
# 74          Hoelscher Unit 1-11   68.35      2.41      0.16    -inf
# 75           HUBBARD TRUST 1-16   62.59      2.14      0.15    0.73
# 76                  Hudson 4-1T    67.9      2.27      0.13    -inf
# 77                    Hufford 3   78.24      2.23      0.13    -inf
# 78                     Hujing 3   72.45      1.96      0.15    -inf
# 79                   J Behnke 1   68.04      2.01      0.16    -inf
# 80                       JACK 2    80.2      2.27      0.09    -inf
# 81                    James C-1   70.84      2.19      0.15    -inf
# 82            Janssen Unit 1-18    78.8      2.17      0.15    -inf
# 83                     Jean 1-2   74.12      2.42      0.15    -inf
# 84                      Jezek 1   72.86      2.15      0.15    -inf
# 85                     Jim 1-19   70.95      2.23      0.15    -inf
# 86                    Johnson 7   66.06      2.44      0.14    -inf
# 87                   Jones 6-12   61.85      2.46      0.16    -inf
# 88                        JPG 1   72.71      2.11      0.15    -inf
# 89                   Kathy 1-24    68.8      2.24      0.14    -inf
# 90                      KK 1-22   66.82      2.42      0.16    -inf
# 91                    Kohman 11    61.2      2.25      0.13    -inf
# 92                  Kratzler 10   63.11      2.41      0.14    -inf
# 93              L&D Donley 20-1    87.2      2.32      0.16    -inf
# 94                      Lilja 1   71.49      2.34      0.14    -inf
# 95                   Lincoln 10   71.63      2.38      0.15    -inf
# 96                   Lincoln 13    65.2      2.42      0.17    -inf
# 97                   Lincoln 15   65.46      2.36      0.18    -inf
# 98                   Lincoln 16   65.41       2.4      0.15    -inf
# 99                   Lincoln 18    70.7      2.42      0.17    -inf
# 100                   Lincoln 2   77.51      2.38      0.19    -inf
# 101                   Lincoln 5   65.66       2.4      0.13    -inf
# 102                   Lincoln 6   66.65      2.39       0.1    -inf
# 103                   Lincoln 7   64.24      2.38      0.13    -inf
# 104                   Lincoln 8   68.81      2.38      0.15    -inf
# 105                   Lincoln 9   74.67      2.38      0.14    -inf
# 106                 LISTER A 39   71.68       2.4      0.18    0.68
# 107                  Loesch C-1   71.58       2.1      0.14    -inf
# 108                   Long 1-13    66.4      2.41      0.13    -inf
# 109                 Long Land 1   63.45      2.43      0.08    -inf
# 110               Manke Trust 1   74.13      2.42      0.13    -inf
# 111                  MATOSH A 8   75.59      2.42      0.11    -inf
# 112               Max Wells C-1   76.67      2.04      0.12    -inf
# 113                    McLeod 1   79.22      2.25      0.15    -inf
# 114              MCMILLIAN 1-14   58.69      2.18      0.14     0.9
# 115                      Mehl 1   68.64       2.2      0.18    -inf
# 116          Meyer Ankerholz 13   68.87      2.22      0.16    -inf
# 117          Meyer Ankerholz 15   71.24      2.15      0.15    -inf
# 118                      MIKE 1   72.77       1.9      0.18    -inf
# 119              Miller Trust 1    74.1      2.05      0.12    -inf
# 120               Moffett 'D' 2   75.69      2.22      0.13    -inf
# 121                  Moos 'A' 2   66.67      2.42      0.14    -inf
# 122               Nightingale 2   70.57      2.27      0.14    -inf
# 123               North River 4   70.01      2.01      0.18    -inf
# 124       ORTH-ALTENBAUMER 1-12   66.75       2.3      0.09    -inf
# 125           Peace Creek 'C' 1   65.32      2.23      0.15    -inf
# 126              Petermann 28 1    63.6       2.2      0.13    -inf
# 127          Pioneer-Adams 2-27   70.57      2.21      0.12    -inf
# 128         Pioneer-Carter 1-14   61.92       2.4      0.12    -inf
# 129       Pioneer-Hathaway 1-27   72.06      2.41      0.15    -inf
# 130           Pioneer-Orth 1-30   64.94       2.4      0.14    -inf
# 131                 Price 'D' 2   65.58      2.19      0.14    -inf
# 132                Proffitt 5-8    67.4      2.07      0.13    -inf
# 133              R. Redden 16-1   79.92      2.45      0.15    -inf
# 134                Ravenstein 1   65.37      2.05      0.12    -inf
# 135                Ravenstein 2   71.91      2.25      0.16    -inf
# 136                 RED JAW 7-2   57.73      2.02      0.14    0.77
# 137                     Reese 4    73.1      2.34      0.13    -inf
# 138                 Remmert 1-4   74.23      2.41      0.15    -inf
# 139                  Ricker C-1   71.22      2.21      0.15    -inf
# 140               Ringwald 1-33   68.28       2.2      0.13    -inf
# 141          Rock Creek Ranch 1   89.78      2.34       0.1    -inf
# 142                    Rogers 2   86.68      2.31       0.2    -inf
# 143                    Rogers 3   86.64      2.31      0.13    -inf
# 144                  S. Rolfs 5   63.98      2.44      0.11    -inf
# 145                  S. ROLFS 6   68.71       1.9      0.11    -inf
# 146            Sam Ainsworth 14   61.45      2.33      0.13    -inf
# 147                    Sara C-1   70.14      2.11      0.16    -inf
# 148                SAWYER #15-1   63.04       2.3      0.18    0.69
# 149                    Scheer 2   66.28       2.3      0.12    -inf
# 150             Schepmann 'A' 5   73.47      2.02      0.15    -inf
# 151        Schepmann Trust 1-27   69.11      2.52      0.23     0.7
# 152                    Schrag 1   64.17      2.31      0.12    -inf
# 153               Schroeder B 3   73.14      2.17       0.1    -inf
# 154                Schulz V1-16   83.02      2.34      0.12    -inf
# 155               Setzkorn 26-1   84.92      2.41      0.13    -inf
# 156                    Simons 2   71.35      2.03      0.14    -inf
# 157              Singleton 1-15   65.37      2.21      0.15    -inf
# 158                 Skiles 28 1   71.46      2.14      0.22    -inf
# 159                    Soeken 1   62.93      2.43      0.12    -inf
# 160             Soukup 'C' 1-14   66.81       2.4      0.11     0.9
# 161      Springer Hollow Farm 2   68.01      2.34      0.12    -inf
# 162       Stoltenberg-Boor 1-17   65.54       2.4      0.14    -inf
# 163    Stoltenberg-Svoboda 2-17   72.05      2.39      0.17    -inf
# 164    Stoltenberg-Svoboda 3-17   70.04      2.41      0.18    -inf
# 165             Swisher, Lyle 1   73.46      2.22      0.13    -inf
# 166             Swisher, Lyle 2   76.04      2.24      0.11    -inf
# 167                    Thelma 1   70.64      2.33      0.11    -inf
# 168                  UKENS #2 2   72.97      2.32       0.2    -inf
# 169                     Unruh 7   66.08      2.45      0.13    -inf
# 170                     Viney 5   73.07      2.28      0.15    -inf
# 171                Vokland 2-32   64.96       2.4      0.15    -inf
# 172              Volkland 'A' 7   64.65      2.21      0.11    -inf
# 173               Volkland 11-5   63.25      2.42      0.15    -inf
# 174               Volkland 12-5   61.09      2.19      0.11    -inf
# 175               Volkland 3-32   67.85      2.26       0.1    -inf
# 176               Volkland 4-32   70.89      2.22      0.15    -inf
# 177               Volkland 5-32   67.29      2.21      0.14    -inf
# 178               Voshell 'D' 1   66.64      2.33       0.1    -inf
# 179                    Warner 2   77.05       2.1      0.15    -inf
# 180                    Watt 1-3   74.94      2.52      0.14    -inf
# 181                 Wilson 1-22   66.97      2.43      0.13    -inf
# 182                WILSON A 452   76.27      2.44      0.17    0.69
# 183                      Wire 4   72.79      2.01      0.15    -inf
# 184            Wonderful Word 1   84.34      2.53      0.17    -inf
# 185         Young Cox Unit 1-27    53.6      2.47      0.15    -inf
